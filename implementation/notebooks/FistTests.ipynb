# %% [markdown]
# # Abstracción de datos

# %%
import mne
mne.set_log_level('WARNING')

EDF_PATH = "./Datasets/aaaaaaaq_s006_t000.edf""

raw = mne.io.read_raw_edf(EDF_PATH, preload=True, verbose=False)

print(f"Canales: {len(raw.ch_names)}")
print(f"Fs: {raw.info['sfreq']} Hz")
print(f"Duración: {raw.times[-1]:.1f} s")
print(f"Canales: {raw.ch_names[:5]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 mne.set_log_level('WARNING')
#       3
#       4 EDF_PATH = "./data/tu_archivo.edf"
#       5
# ----> 6 raw = mne.io.read_raw_edf(EDF_PATH, preload=True, verbose=False)
#       7
#       8 print(f"Canales: {len(raw.ch_names)}")
#       9 print(f"Fs: {raw.info['sfreq']} Hz")
#
# File c:\Users\ferch\Documents\Various\EngineeringDesignAndInnovation\hybrid-ai-epilepsy-diagnosis\.venv\Lib\site-packages\mne\io\edf\edf.py:2009, in read_raw_edf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, exclude_after_unique, verbose)
#    1888 @fill_doc
#    1889 def read_raw_edf(
#    1890     input_fname,
#    (...)   1902     verbose=None,
#    1903 ) -> RawEDF:
#    1904     """Reader function for EDF and EDF+ files.
#    1905
#    1906     Parameters
# ...
